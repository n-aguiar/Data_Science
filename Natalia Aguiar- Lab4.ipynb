# %% [markdown]
# <a href="https://colab.research.google.com/github/n-aguiar/Data_Science/blob/main/Natalia%20Aguiar-%20Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #4

# %%
import numpy as np
import matplotlib.pyplot as plt #importing libraries

# %%
x = np.array([1,2,3,4])

# %%
# population

# %%
np.sum(x) #adding all the numbers in the ray
# Out:
# 10

# %%
x.shape[0] #shaping the variables of "x"
# Out:
# 4

# %%
np.sum(x)/x.shape[0] #diving sum by the shape calculated
# Out:
# 2.5

# %%
def mean(x): #defining the variable to return the equation
    return np.sum(x)/x.shape[0]

# %%
mean(x)
# Out:
# 2.5

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
x - mean(x) #testing
# Out:
# array([-1.5, -0.5,  0.5,  1.5])

# %%
(x - mean(x))**2
# Out:
# array([2.25, 0.25, 0.25, 2.25])

# %%
 def var(x): #renaming variable
    return mean((x - mean(x))**2)

# %%
def std(x): #to return a single digit
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 2.5

# %%
var(x)
# Out:
# 1.25

# %%
std(x)
# Out:
# 1.118033988749895

# %% [markdown]
# ### Random Number Generator

# %% [markdown]
# $y=mx+b$

# %%
m = 75                 # multiplier
b = 74                 # increment
n = 65537              # modulus

# %%
x = 58      # seed value

# %%
X = np.zeros(50000,)

# %%
x = (m * x + b) % n #naming the equation

# %%
for i in range(X.shape[0]): #making the variable to run the equation/code for all integers

    x = (m * x + b) % n
    
    X[i] = x

# %%
X
# Out:
# array([ 4189., 52101., 40966., ..., 26762., 41114.,  3385.])

# %%
X /= np.max(X) #naming the variable

# %%
plt.plot(X[:100],'.') #plottting

# %%
plt.hist(X); #shows how many dots of each one

# %%
plt.hist(X,100); #hist0ogram for 100 numbers

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %%
X
# Out:
# array([0.06392004, 0.7950103 , 0.62510109, ..., 0.40836194, 0.62735943,
#        0.05165179])

# %%
X #testing the varible again
# Out:
# array([0.8536898 , 0.54964395, 0.48517408, ..., 0.55080994, 0.09472706,
#        0.82662079])

# %% [markdown]
# ### Random Numbers

# %%
X = np.random.random(50000,) #rando number generator

# %%
X
# Out:
# array([0.8536898 , 0.54964395, 0.48517408, ..., 0.55080994, 0.09472706,
#        0.82662079])

# %%
plt.hist(X,100); #plotting out 100 of the rando numbers

# %%
np.random.random() #singular random number below 0
# Out:
# 0.23702125934929752

# %%
r = np.random.random() #making the random number =r

# %%
r
# Out:
# 0.769222112824199

# %%
r = np.random.randint(1,10) #random number from 1-10 (0-9)

# %%
r
# Out:
# 5

# %%
r = np.random.randint(0,3,size=(1)) #choses a number 0-2 for three options

# %%
r[0]
# Out:
# 2

# %%
game = ['rock', 'paper', 'scissors'] #making a game of the code 
                                    #the order of the names corresponds to the number in the array [0,1,2]

# %%
game[r[0]]
# Out:
# 'paper'

# %%
p1 = np.random.randint(0,3,size=(1))[0] #players choice
p2 = np.random.randint(0,3,size=(1))[0] #players choice

# %%
p1,p2
# Out:
# (1, 1)

# %%
p1 = np.random.randint(0,3,size=(1))[0] #players choice with name
p2 = np.random.randint(0,3,size=(1))[0] #players choice with name
game[p1],game[p2]
# Out:
# ('paper', 'scissors')

# %%
import numpy as np #importing library

# %%
np.random.randn()
# Out:
# -1.0576285906106295

# %%
numbers  = np.random.randn(2,4) #naming the variable for range of 2-4

# %%
numbers.shape
# Out:
# (2, 4)

# %%
numbers = numbers.reshape(-1)

# %%
numbers.shape
# Out:
# (2, 4)

# %%
# numbers= np.array([1,2,2,3,3,3,4,4,4,4])

# %%
numbers = np.random.randn(100000,)

# %%
numbers.shape
# Out:
# (100000,)

# %%
plt.hist(numbers,100);

# %%
numbers = np.random.rand(1000000,) #renaming the variable to run new number

# %%
plt.hist(numbers,100);

# %%
np.random.seed(12345)
data = np.random.randn(2, 100)

plt.figure(1, figsize=(9, 9))


plt.subplot(2,2,1) #first sub plot
plt.hist(data[0])

plt.subplot(2,2,2) #second sub plot
plt.scatter(data[0], data[1])

plt.subplot(2,2,3) #third sub plot
plt.plot(data[0], data[1])

plt.subplot(2,2,4) #fourth subplot
plt.hist2d(data[0], data[1])

plt.show() #plotting all of the graphs together

# %% [markdown]
# Normal Dist Data

# %%
x = 50*np.random.randn(10000) #renaming variable x

# %%
plt.hist(x);

# %%
x = np.random.rand(1000,)

# %%
plt.hist(x**2); #plotting the histogram of the new x values

# %%
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

# %%
n,bins,patches = plt.hist(x)

# %%
bins #puts the numbers in a string
# Out:
# array([ 47.67401067,  58.75290006,  69.83178945,  80.91067884,
#         91.98956823, 103.06845762, 114.14734702, 125.22623641,
#        136.3051258 , 147.38401519, 158.46290458])

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(y)  #naming variable y

# %%
num_bins = 50
n,bins,patches = plt.hist(x, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y) #plotting the numbers in bar graphs with smooth line estimate

# %%
def mean(x): #redefining mean(x)for new x
    return np.sum(x)/x.shape[0]

# %%
def var(x): #redefining var(x)for new x
    return mean((x - mean(x))**2)

# %%
def std(x): #redefining std(x) for new x
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 100.08288406198832

# %%
std(x)
# Out:
# 14.975014354444243

# %% [markdown]
# # Normal Random Number Generator

# %%
#CDF PDF

# %%
x = np.linspace(-10,10,100) #start,stop,and how many stops in between
y = 2.71**(-x**2) 
plt.plot(x,y) #plotting said graph from points

# %% [markdown]
# $e^{-x^2}$

# %% [markdown]
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/4abaca87a10ecfa77b5a205056523706fe6c9c3f)

# %%
def normal_pdf(x,mu,sigma): #definig new variable to give answwer 
  
  return (1/(np.sqrt(2*np.pi*sigma**2)))*np.exp((-(x-mu)**2)/(2*sigma**2))

# %%
x = np.linspace(-6,6,1000) #numbers from -6 to 6 with 1,000 stops in between

# %%
mu = 0

# %%
sigma = 1

# %%
pdf= normal_pdf(x,mu,sigma) #Use Normal for demo, replace with custom function pdf

# %%
plt.plot(x,pdf,'.')
plt.plot(x,pdf,'g.') #plotting new linspace

# %%
def partial_sums(x): #initializing term to run code for all numbers in the range

  y = np.zeros(x.shape)
  
  for n in range(x.shape[0]):
    
    y[n] = np.sum(x[0:n])
    
  y = y / np.max(y)
    
  return y

# %%
cdf = partial_sums(pdf) #naming variable

# %%
plt.plot(x,cdf,'.'); #plotting

# %%
d_cdf = cdf[1:] - cdf[0:-1] #Demo to show that the diff of the cdf gives you back the pdf
plt.plot(x[1:],d_cdf,'.');  #Not required for sampling

# %%
plt.plot(cdf,x,'.'); #flipped the x, and y

# %%
def find_nearest(array, value): #chain and defining

  idx = np.argmin(np.abs(array - value))
  
  return idx

# %%
find_nearest(cdf, 0.1) #testing out code
# Out:
# 393

# %%
x[393]
# Out:
# -1.2792792792792795

# %%
xr = np.random.random((10000,)) #naming another value for random numbers

# %%
w = np.zeros(xr.shape[0]) #another variable to not run the variable above

for i in range(xr.shape[0]):
  
  w[i] = x[find_nearest(cdf, xr[i])]

# %%
w.shape
# Out:
# (10000,)

# %%
plt.hist(w,50); #histogram for w

# %%
num_bins = 50 #bar graph and smoooth line
n,bins,patches = plt.hist(w, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %% [markdown]
# # Random Color

# %%
import numpy as np #importing libraries
import matplotlib.pyplot as plt

# %%
z = np.random.randint(0,255,size=(1,1,3)) #adding random color numbers

# %%
z #testing out
# Out:
# array([[[143,  35, 173]]])

# %%
z = np.random.randint(0,255,size=(10,10,3)) #renaming z

# %%
plt.imshow(z)#plotting out the colors

# %%
z = np.zeros((10,10,3))

# %%
z.shape
# Out:
# (10, 10, 3)

# %%
plt.imshow(z) #plotting the color that occurs at the z value

# %%
z = 0*np.ones((10,10,3))

# %%
plt.imshow(z)

# %%
z = 255*np.ones((10,10,3))

# %%
plt.imshow(z) #plotting the color that is the new z variable
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = np.ones((10,10,3)) #plotting colors

z[:,:,0] = 1
z[:,:,1] = 0
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3)) #plotting colors changing the z row from 0 to 1

z[:,:,0] = 0
z[:,:,1] = 1
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3)) #plotting color at 0,0,1

z[:,:,0] = 0
z[:,:,1] = 0
z[:,:,2] = 1

plt.imshow(z)

# %%
plt.hist(np.random.randn(1000,)/6 + 1/2) #histogram of the numbers
# Out:
# (array([  7.,  37., 123., 236., 271., 208.,  87.,  29.,   1.,   1.]),
#  array([-0.01460643,  0.10288311,  0.22037265,  0.3378622 ,  0.45535174,
#          0.57284128,  0.69033082,  0.80782037,  0.92530991,  1.04279945,
#          1.16028899]),
#  <a list of 10 Patch objects>)

# %%
for _ in range(100): #Plotting all the numbers for the colors
    z = np.ones((10,10,3))

    r = np.random.randn()/6 + 1/2
    g = np.random.randn()/6 + 1/2
    b = np.random.randn()/6 + 1/2

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
# Out:
# 0.7536058641545114 0.4804028069332736 0.5187001960343517
# 0.5579808962176581 0.6053164981678807 0.07456101372426555
# 0.5501679386863854 0.5245332506088453 0.4818278271319138
# 0.5494042617102706 0.48684166934131207 0.7612056546490487
# 0.6590645367328695 0.21976994504205583 0.3515968317756101
# 0.18700722116244478 0.4031003080923761 0.5483777535175898
# 0.5872484988056977 0.7218901759558904 0.11822939429014384
# 0.6686845603250008 0.2861054634946597 0.39252849908865806
# 0.7201445570720871 0.7106839123972207 0.3577778045230069
# 0.6037957010240735 0.4066832923972454 0.6110337186562027
# 0.5960822641237415 0.5954141314495041 0.27692394464593884
# 0.14661811766887817 0.7361268095171345 0.8049711595863117
# 0.2806088395094207 0.16061591416285875 0.5207263331901787
# 0.6218999586552941 0.2699721696678239 0.3644723490160532
# 0.5500027441597222 0.5207872755093107 0.42314881670746757
# 0.5095900834089601 0.5413098726742271 0.48605087121415336
# ...

# %%
for i in range(100): #plotting all the colors for the values 

    z = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
    plt.show()
# Out:
# 0.04565498822545755 0.9018898573486791 0.705208077750151
# 0.13305483655332895 0.25890296242849375 0.6489579287772617
# 0.8783731990594899 0.28745820118490173 0.666835928055837
# 0.0551020516876527 0.8658629291949117 0.7215541553165531
# 0.39234003199970635 0.2757218041612137 0.9641026630915088
# 0.9159365908320668 0.11027962107317058 0.8072761400765021
# 0.23329384510357654 0.1917033704991179 0.48858093037942296
# 0.8471817132530649 0.37697930192164575 0.15790295872332627
# 0.3082442997790674 0.5595835726726746 0.9986117608370421
# 0.7793244744291918 0.27119450522065003 0.8844584754537861
# 0.13603917476056093 0.49578363406473946 0.42346444664614036
# 0.7231345024392833 0.7552849963974201 0.7854530022761469
# 0.21021484989220673 0.932032709727563 0.33810937505075567
# 0.5279536250921552 0.7753448906140769 0.1692802772279668
# 0.2270628090478598 0.5406860799590804 0.6170259884594712
# 0.07101146705603745 0.46785086340433824 0.9597427214632244
# ...

# %%
z1 = np.ones((10,10,3)) #ploting the gradient
z1[:,:,0] = np.random.rand()
z1[:,:,1] = np.random.rand()
z1[:,:,2] = np.random.rand()

z2 = np.ones((10,10,3))
z2[:,:,0] = np.random.rand()
z2[:,:,1] = np.random.rand()
z2[:,:,2] = np.random.rand()

zavg = (z1+z2)/2

z1a = (z1+zavg)/2
z2a = (z2+zavg)/2

z3 = np.hstack((z1,z1a,zavg,z2a,z2))

plt.imshow(z3);
plt.show()

# %%
for i in range(100): #plotting all the gradients
    
    z1 = np.ones((10,10,3))
    z1[:,:,0] = np.random.rand()
    z1[:,:,1] = np.random.rand()
    z1[:,:,2] = np.random.rand()

    z2 = np.ones((10,10,3))
    z2[:,:,0] = np.random.rand()
    z2[:,:,1] = np.random.rand()
    z2[:,:,2] = np.random.rand()

    zavg = (z1+z2)/2

    z1a = (z1+zavg)/2
    z2a = (z2+zavg)/2

    z3 = np.hstack((z1,z1a,zavg,z2a,z2))

    plt.imshow(z3);
    plt.show()

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z2 = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    z1[:,:,0] = r
    z1[:,:,1] = g
    z1[:,:,2] = b
    
    z2[:,:,0] = 1-r
    z2[:,:,1] = 1-g
    z2[:,:,2] = 1-b

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()

# %% [markdown]
# https://lospec.com/palette-list

# %%
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib
import imageio
from PIL import Image

def get_colors_lospec(url): 
    im = imageio.imread(url)
    rgb_list = (im/255)[0,:,0:3]
    float_list = list(np.linspace(0,1,len(rgb_list)))    
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp

# %%
url = 'https://lospec.com/palette-list/agb-32x.png' #defining the url

# %%
url = 'https://lospec.com/palette-list/agb-1x.png'

# %%
url = 'https://lospec.com/palette-list/moondrom-1x.png'

# %%
im = imageio.imread(url) #plots the most recent url code ran

# %%
plt.imshow(im); #plots the url gradient

# %%
z = np.random.randint(0,255,size=(10,10))

# %%
plt.imshow(z, cmap=get_colors_lospec(url))
plt.colorbar();

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05] #plots
z = np.sqrt(x**2 + y**2)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05] #plots 
z = np.sin(3*y)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05] #plots
z = np.sin(3*y)*np.sin(3*x)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
